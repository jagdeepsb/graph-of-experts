# %%
from src.data import CelebADataset

d = CelebADataset()
# Out:
# Files already downloaded and verified
# Splitting data by Black_Hair:   8%|▊         | 12307/162770 [00:01<00:20, 7442.59it/s]

# %%
# visualize some of the dataset
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(1, 5, figsize=(20, 4))

for i in range(5):
    img, attr, target = d[len(d)-i-1]
    ax[i].imshow(img)
    ax[i].set_title(f"Target: {target.item()}")
    ax[i].set_xlabel(d.attr_dict[attr])
